# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %%
sales=pd.read_csv('walmart-sales-dataset-of-45stores.csv')
sales.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
sales.tail(5)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
sales.describe(include='all')
# Out:
#               Store        Date  Weekly_Sales  Holiday_Flag  Temperature  \
# count   6435.000000        6435  6.435000e+03   6435.000000  6435.000000
# unique          NaN         143           NaN           NaN          NaN
# top             NaN  05-02-2010           NaN           NaN          NaN
# freq            NaN          45           NaN           NaN          NaN
# mean      23.000000         NaN  1.046965e+06      0.069930    60.663782
# std       12.988182         NaN  5.643666e+05      0.255049    18.444933
# min        1.000000         NaN  2.099862e+05      0.000000    -2.060000
# 25%       12.000000         NaN  5.533501e+05      0.000000    47.460000
# 50%       23.000000         NaN  9.607460e+05      0.000000    62.670000
# 75%       34.000000         NaN  1.420159e+06      0.000000    74.940000
# max       45.000000         NaN  3.818686e+06      1.000000   100.140000
#
#          Fuel_Price          CPI  Unemployment
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
sales.shape
# Out:
# (6435, 8)

# %% [markdown]
# Calculated fields

# %%
sales['Date']=pd.to_datetime(sales['Date'])
sales['Year']=sales['Date'].dt.year
sales['Month']=sales['Date'].dt.month
sales['Day']=sales['Date'].dt.day
sales['MonthYear_value'] = sales['Date'].dt.to_period('M')
sales.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-05-02    1643690.90             0        42.31       2.572
# 1      1 2010-12-02    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Year  Month  Day Monthyear_value MonthYear_value
# 0  211.096358         8.106  2010      5    2         2010-05         2010-05
# 1  211.242170         8.106  2010     12    2         2010-12         2010-12
# 2  211.289143         8.106  2010      2   19         2010-02         2010-02
# 3  211.319643         8.106  2010      2   26         2010-02         2010-02
# 4  211.350143         8.106  2010      5    3         2010-05         2010-05

# %%
sales['Date']=pd.to_datetime(sales['Date'])
sales['Year']=sales['Date'].dt.year
sales['Month']=sales['Date'].dt.month
sales['Day']=sales['Date'].dt.day
sales['MonthYear_value']=sales['Date'].dt.to_period('M')
sales['Quarter_value']=sales['Date'].dt.to_period('Q')
sales.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-05-02    1643690.90             0        42.31       2.572
# 1      1 2010-12-02    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Year  Month  Day Monthyear_value MonthYear_value  \
# 0  211.096358         8.106  2010      5    2         2010-05         2010-05
# 1  211.242170         8.106  2010     12    2         2010-12         2010-12
# 2  211.289143         8.106  2010      2   19         2010-02         2010-02
# 3  211.319643         8.106  2010      2   26         2010-02         2010-02
# 4  211.350143         8.106  2010      5    3         2010-05         2010-05
#
#   Quarter_value
# 0        2010Q2
# 1        2010Q4
# ...

# %%
sales[['Year','Store','Holiday_Flag','Temperature','CPI','Fuel_Price']].hist(bins=25,figsize=(25,25));

# %%
sales_year=sales.groupby(['MonthYear_value']).sum()
sales_year[['Weekly_Sales']].plot(figsize=(16,6),subplots=True);

# %%
sales_year=sales.groupby(['MonthYear_value']).sum()
sales_year[['Weekly_Sales']].plot(figsize=(16,6), subplots=True);

# %%
sales_year
# Out:
#                  Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# MonthYear_value
# 2010-01           1035  4.223988e+07             0      3144.06     123.045
# 2010-02           4140  1.915869e+08             0      9324.79     493.958
# 2010-03           4140  1.862262e+08             0      9740.74     507.286
# 2010-04           4140  1.838118e+08             0     11086.93     516.198
# 2010-05           6210  2.806119e+08             0     14713.65     766.327
# 2010-06           3105  1.424361e+08             0     10455.89     374.927
# 2010-07           4140  1.842664e+08             0     13716.76     505.106
# 2010-08           4140  1.845381e+08             0     13383.78     500.114
# 2010-09           4140  1.797041e+08             0     12584.09     499.988
# 2010-10           5175  2.311201e+08            45     13087.01     640.842
# 2010-11           3105  1.587731e+08            45      7675.64     387.810
# ...

# %%
sales_year['Weekly_Sales']
# Out:
# MonthYear_value
# 2010-01    4.223988e+07
# 2010-02    1.915869e+08
# 2010-03    1.862262e+08
# 2010-04    1.838118e+08
# 2010-05    2.806119e+08
# 2010-06    1.424361e+08
# 2010-07    1.842664e+08
# 2010-08    1.845381e+08
# 2010-09    1.797041e+08
# 2010-10    2.311201e+08
# 2010-11    1.587731e+08
# 2010-12    3.235716e+08
# 2011-01    2.119657e+08
# 2011-02    1.876092e+08
# 2011-03    1.365205e+08
# 2011-04    2.789693e+08
# 2011-05    1.828017e+08
# 2011-06    1.401936e+08
# 2011-07    2.244611e+08
# 2011-08    1.880810e+08
# 2011-09    2.310323e+08
# 2011-10    1.837193e+08
# 2011-11    2.534703e+08
# 2011-12    2.293760e+08
# 2012-01    1.722207e+08
# 2012-02    1.428296e+08
# 2012-03    2.307397e+08
# 2012-04    1.825428e+08
# 2012-05    1.422830e+08
# 2012-06    2.923883e+08
# 2012-07    1.845865e+08
# 2012-08    1.916126e+08
# 2012-09    1.797959e+08
# 2012-10    1.880794e+08
# 2012-11    4.692588e+07
# 2012-12    4.612851e+07
# Freq: M, Name: Weekly_Sales, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(12,6))
corr=sales.corr()
sns.heatmap(corr, annot=True,cmap="RdBu",vmin=-1,vmax=1,fmt=".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Impact of Unemploymemnt on sales

# %%
print("The correlation coefficient between Weekly_Sales and Holiday_Flag is:",np.corrcoef(sales['Weekly_Sales'],sales['Unemployment'])[1,1])
# Out:
# The correlation coefficient between Weekly_Sales and Holiday_Flag is: 1.0
